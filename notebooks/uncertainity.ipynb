# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
os.chdir("/Users/samyuktareddy/Desktop/MOF Gas absorption")
df = pd.read_csv("outputs/candidates/topk_candidates.csv").head(5)

# %%
df["std"] = df["pred_uptake_gnn_std"].fillna(df["pred_uptake_rf_std"])

# %%
plt.figure(figsize=(10, 6))
plt.bar(df["refcode"], df["screen_score"], yerr=df["std"], capsize=5, color="skyblue")
plt.ylabel("Predicted CO₂ Uptake")
plt.title("Top 5 MOFs: Screen Score with Uncertainty")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig("outputs/plots/top5_errorbars.png")
plt.show()
